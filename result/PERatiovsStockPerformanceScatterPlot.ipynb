# %%
plt.figure()
df_clean = df[df["forward_return"] < df["forward_return"].quantile(0.99)]
plt.scatter(df_clean["pe_ratio"], df_clean["forward_return"], alpha=0.5)

plt.xlabel("Normalized P/E Ratio")
plt.ylabel("Forward Return")
plt.title("P/E Ratio vs Stock Performance (Outliers Removed)")

plt.show()

# %%
print(df["pe_ratio"].describe())
# Out:
# count    11131.000000
# mean         0.502291
# std          0.287101
# min          0.005839
# 25%          0.252070
# 50%          0.503125
# 75%          0.752055
# max          1.000000
# Name: pe_ratio, dtype: float64
